# %%
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Importing Data
df1=pd.read_csv('data.csv')
df1.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2010-08-27   9982.179688  10159.879883   9936.620117  10150.650391
# 1  2010-08-30  10145.580078  10150.570313  10007.679688  10009.730469
# 2  2010-08-31  10006.419922  10073.379883   9941.839844  10014.719727
# 3  2010-09-01  10016.009766  10279.080078  10016.009766  10269.469727
# 4  2010-09-02  10270.080078  10320.370117  10253.959961  10320.099609
#
#       Adj Close     Volume
# 0  10150.650391  207760000
# 1  10009.730469  150480000
# 2  10014.719727  255420000
# 3  10269.469727  205710000
# 4  10320.099609  149930000

# %%
# Importing Data
df=pd.read_csv('data11.csv')
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2010-08-27   9982.179688  10159.879883   9936.620117  10150.650391
# 1  2010-08-30  10145.580078  10150.570313  10007.679688  10009.730469
# 2  2010-08-31  10006.419922  10073.379883   9941.839844  10014.719727
# 3  2010-09-01  10016.009766  10279.080078  10016.009766  10269.469727
# 4  2010-09-02  10270.080078  10320.370117  10253.959961  10320.099609
#
#       Adj Close     Volume
# 0  10150.650391  207760000
# 1  10009.730469  150480000
# 2  10014.719727  255420000
# 3  10269.469727  205710000
# 4  10320.099609  149930000

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %%
#Checking shape
df.shape
# Out:
# (2014, 7)

# %%
# Checking Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014 entries, 0 to 2013
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2014 non-null   object
#  1   Open       2014 non-null   float64
#  2   High       2014 non-null   float64
#  3   Low        2014 non-null   float64
#  4   Close      2014 non-null   float64
#  5   Adj Close  2014 non-null   float64
#  6   Volume     2014 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 110.3+ KB

# %%
#Checking Null Values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# checking No. Of Unique values
df.nunique()
# Out:
# Date         2014
# Open         2007
# High         2009
# Low          2006
# Close        2004
# Adj Close    2004
# Volume       1919
# dtype: int64

# %%
# Date in the form of object we have to convert datetime stamp
df['Date']=pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
# Statistical Description
df.describe().T
# Out:
#             count          mean           std           min           25%  \
# Open       2014.0  1.675688e+04  3.985885e+03  9.982180e+03  1.310424e+04
# High       2014.0  1.683596e+04  3.992889e+03  1.007338e+04  1.317567e+04
# Low        2014.0  1.667666e+04  3.977350e+03  9.936620e+03  1.304543e+04
# Close      2014.0  1.676276e+04  3.984242e+03  1.000973e+04  1.310728e+04
# Adj Close  2014.0  1.676276e+04  3.984242e+03  1.000973e+04  1.310728e+04
# Volume     2014.0  1.699523e+08  1.072222e+08  8.410000e+06  9.486500e+07
#
#                     50%           75%           max
# Open       1.656654e+04  1.828270e+04  2.658428e+04
# High       1.665289e+04  1.835006e+04  2.661671e+04
# Low        1.650036e+04  1.820506e+04  2.643534e+04
# Close      1.657127e+04  1.828791e+04  2.661671e+04
# Adj Close  1.657127e+04  1.828791e+04  2.661671e+04
# Volume     1.284750e+08  2.177400e+08  8.239400e+08

# %%
df.drop_duplicates(inplace=True)
df.shape#No Duplicates..shape matched
# Out:
# (2014, 7)

# %%
#seperate numerical and categorical columns
df_num=df.select_dtypes(np.number)
df_cat=df.select_dtypes("object")
df_tar=df['Close']

# %%
df_num.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## UNIVARIATE

# %%
sns.set_style("darkgrid")
sns.set(font_scale=2)
fig,ax=plt.subplots(2,3,figsize=(30,15))
for i,subplot in zip(list(df_num.columns),ax.flatten()):
    sns.boxplot(df_num[i],color='r',ax=subplot)
plt.show()

# %% [markdown]
# ## Comment:
#     ** Volume feature having outliers.

# %%
#Normality Checking
fig,ax=plt.subplots(2,3,figsize=(30,15))
for i,subplot in zip(list(df_num.columns),ax.flatten()):
    sns.distplot(df_num[i],color='b',ax=subplot)
plt.show()

# %% [markdown]
# ## Comment:
#      ** All features are not Normally Distributed.

# %% [markdown]
# ## BIVARIATE

# %%
# Check correlation of numerical values using scatter plot
fig,ax=plt.subplots(2,3,figsize=(30,15))
for i,subplot in zip(list(df_num.columns),ax.flatten()):
    sns.scatterplot(x=df_num[i],y=df['Close'],color='r',ax=subplot)
plt.show()

# %% [markdown]
# ## Comment:
#     ** Except Volume every feature having linearly related to the Target(Close) feature.

# %% [raw]
# # Check correlation and distribution of numerical values using scatter plot
# fig,ax=plt.subplots(2,3,figsize=(30,15))
# for i,j in zip(list(df_num.columns),ax.flatten()):
#     sns.jointplot(x=df_num[i],y=df['Close'],color='b',ax=j)
# plt.show()

# %% [markdown]
# ## MULTIVARIATE

# %%
sns.pairplot(df_num)

# %%
# Correlation matrix
sns.heatmap(df.corr(),annot=True)

# %%
df_num.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
from sklearn.preprocessing import Normalizer
fitt=Normalizer()
df_num[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]=fitt.fit_transform(df_num)

# %% [markdown]
# aa=np.array(df['Date']).reshape(-1,1)

# %% [markdown]
# from sklearn.preprocessing import OrdinalEncoder
# fittt=OrdinalEncoder()
# df['Date']=fittt.fit_transform(aa)

# %% [markdown]
# x=np.array(indep.drop('Close',axis=1))
# y=np.array(indep['Close'])

# %%
x=df_num.drop('Close',axis=1)
y=df_num['Close']

# %%
x.head()
# Out:
#        Open      High       Low  Adj Close  Volume
# 0  0.000048  0.000049  0.000048   0.000049     1.0
# 1  0.000067  0.000067  0.000067   0.000067     1.0
# 2  0.000039  0.000039  0.000039   0.000039     1.0
# 3  0.000049  0.000050  0.000049   0.000050     1.0
# 4  0.000068  0.000069  0.000068   0.000069     1.0

# %%
y.head()
# Out:
# 0    0.000049
# 1    0.000067
# 2    0.000039
# 3    0.000050
# 4    0.000069
# Name: Close, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D
from keras import layers
from keras import optimizers

# %%
# Create training and test split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train.shape
# Out:
# (1409, 5)

# %%
# building a linear stack of layers with the sequential model

model = Sequential()

# %%
# hidden layer

model.add(Dense(16, input_shape=(5,), activation='relu',kernel_initializer='random_normal'))

# %%
# output layer

model.add(Dense(1,activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 16)                96
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the sequential model

model.compile(optimizer='rmsprop', loss='mse',metrics=['mae'])

# %%
# training the model for 10 epochs

model.fit(x_train, y_train, batch_size=12, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 118/118 [==============================] - 0s 3ms/step - loss: 2.8609e-07 - mae: 4.5683e-04 - val_loss: 2.3633e-07 - val_mae: 4.8177e-04
# Epoch 2/10
# 118/118 [==============================] - 0s 2ms/step - loss: 2.5325e-07 - mae: 4.8974e-04 - val_loss: 2.2439e-07 - val_mae: 4.6921e-04
# Epoch 3/10
# 118/118 [==============================] - 0s 1ms/step - loss: 2.5843e-07 - mae: 4.9625e-04 - val_loss: 2.2226e-07 - val_mae: 4.6695e-04
# Epoch 4/10
# 118/118 [==============================] - 0s 1ms/step - loss: 2.4437e-07 - mae: 4.5682e-04 - val_loss: 3.6290e-07 - val_mae: 5.9889e-04
# Epoch 5/10
# 118/118 [==============================] - 0s 1ms/step - loss: 2.5456e-07 - mae: 4.9259e-04 - val_loss: 2.3356e-07 - val_mae: 4.7890e-04
# Epoch 6/10
# 118/118 [==============================] - 0s 1ms/step - loss: 2.5941e-07 - mae: 5.0036e-04 - val_loss: 2.5925e-07 - val_mae: 5.0500e-04
# Epoch 7/10
# ...

# %%
mae,mse = model.evaluate(x_test,y_test)
# Out:
# 19/19 [==============================] - 0s 999us/step - loss: 2.1669e-07 - mae: 4.6094e-04
